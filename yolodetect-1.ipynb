# %%
from ultralytics import YOLO

model = YOLO("/home/rokey/cobot_ws/src/cobot2_ws/pick_and_place_text/resource/yolov8n_nuts_obb.pt")

results=model.predict(source=6, show=True)
# Out:
# ...
# QFontDatabase: Cannot find font directory /home/choijinwoo/.local/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/choijinwoo/.local/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/choijinwoo/.local/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/choijinwoo/.local/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...
